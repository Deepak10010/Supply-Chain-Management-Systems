# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('SCMS Dataset.csv')
df.head()
# Out:
#       ID Project Code PQ # PO / SO # ASN/DN #       Country Managed By  \
# 0  11906   114-UG-T01  NaN  SO-17770   DN-998        Uganda   PMO - US
# 1  12533   110-ZM-T01  NaN  SO-16670   DN-993        Zambia   PMO - US
# 2  12544   114-UG-T01  NaN  SO-17700   DN-992        Uganda   PMO - US
# 3  11291   114-UG-T01  NaN  SO-17830   DN-990        Uganda   PMO - US
# 4  11954   104-CI-T01  NaN  SO-11850   DN-988  Cote dIvoire   PMO - US
#
#   Fulfill Via Vendor INCO Term Shipment Mode  ... Unit of Measure (Per Pack)  \
# 0    From RDC              NaN         Truck  ...                         30
# 1    From RDC              NaN         Truck  ...                         60
# 2    From RDC              NaN           Air  ...                         60
# 3    From RDC              NaN           Air  ...                         60
# 4    From RDC              NaN           Air  ...                         30
#
#   Line Item Quantity Line Item Value Pack Price Unit Price  \
# ...

# %% [markdown]
# Meta Data
#
# * Project Code - Code assigned to the project.
# * PQ # - Purchase Quotation number.
# * PO / SO #: Purchase Order / Sales Order number.
# * 'ASN/DN #': Advance Shipment Notice / Delivery Note number.
# * 'Country': The country where the order is being shipped.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          7643 non-null   object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              4920 non-null   object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  7643 non-null   object
#  11  PO Sent to Vendor Date        4592 non-null   object
# ...

# %%
df = df.drop('ID', axis=1)

# %%
df
# Out:
#       Project Code       PQ #    PO / SO #   ASN/DN #       Country  \
# 0       114-UG-T01        NaN     SO-17770     DN-998        Uganda
# 1       110-ZM-T01        NaN     SO-16670     DN-993        Zambia
# 2       114-UG-T01        NaN     SO-17700     DN-992        Uganda
# 3       114-UG-T01        NaN     SO-17830     DN-990        Uganda
# 4       104-CI-T01        NaN     SO-11850     DN-988  Cote dIvoire
# ...            ...        ...          ...        ...           ...
# 10319   102-BI-T30  FPQ-12602     SO-46023    DN-3739       Burundi
# 10320   104-CI-T30  FPQ-13142     SO-47135    DN-3798  Cote dIvoire
# 10321   108-VN-T30  FPQ-10811  SCMS-164530  ASN-18730       Vietnam
# 10322   108-VN-T01        NaN   SCMS-46550   ASN-4488       Vietnam
# 10323   107-RW-T01        NaN   SCMS-14630   ASN-1253        Rwanda
#
#       Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 0       PMO - US     From RDC              NaN         Truck
# ...

# %%
top_project_codes = df['Project Code'].value_counts().index[:10]
df_top_project_codes = df[df['Project Code'].isin(top_project_codes)]
average_pack_price = df_top_project_codes.groupby('Project Code')['Pack Price'].mean()

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'orange', 'purple', 'pink']

plt.figure(figsize=(10,5))
plt.bar(average_pack_price.index, average_pack_price.values, color=colors)
plt.xlabel('Project Code')
plt.ylabel('Average Pack Price')
plt.title('Average Pack Price by Project Code')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This bar chart shows the average pack price for each of the top 10 project codes. The height of each bar represents the average pack price for the corresponding project code.
#
# From this chart, we can observe that:
#
# The project code '103-ZW-T01' has the highest average pack price among the top 10 project codes.
# The project codes '102-ZM-T01' and '103-ZW-T01' have relatively higher average pack prices compared to the other project codes.
# The project code '102-ZM-T01' has the lowest average pack price among the top 10 project codes.
# This information can be useful for understanding how pack prices vary across different project codes. For example, if you are interested in cost optimization, you might want to investigate why some project codes have higher average pack prices than others.

# %%
# Select top 10 PQ# by number of shipments for clearer visualization
top_pq = df['PQ #'].value_counts().index[:10]
df_top_pq = df[df['PQ #'].isin(top_pq)]

average_pack_price_pq = df_top_pq.groupby('PQ #')['Pack Price'].mean()

plt.figure(figsize=(10,5))
plt.bar(average_pack_price_pq.index, average_pack_price_pq.values, color=colors)
plt.xlabel('PQ #')
plt.ylabel('Average Pack Price')
plt.title('Average Pack Price by PQ #')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This visualization allows us to compare the average pack price across different PQ#. As you can see, the average pack price varies significantly between different PQ#.

# %%
# Select top 10 PO/SO# by number of shipments for clearer visualization
top_po_so = df['PO / SO #'].value_counts().index[:10]
df_top_po_so = df[df['PO / SO #'].isin(top_po_so)]

average_pack_price_po_so = df_top_po_so.groupby('PO / SO #')['Pack Price'].mean()

plt.figure(figsize=(10,5))
plt.bar(average_pack_price_po_so.index, average_pack_price_po_so.values, color=colors)
plt.xlabel('PO / SO #')
plt.ylabel('Average Pack Price')
plt.title('Average Pack Price by PO / SO #')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This visualization allows us to compare the average pack price across different PO/SO#. As you can see, the average pack price varies significantly between different PO/SO#.

# %%
# Select top 10 ASN/DN# by number of shipments for clearer visualization
top_asn_dn = df['ASN/DN #'].value_counts().index[:10]
df_top_asn_dn = df[df['ASN/DN #'].isin(top_asn_dn)]

average_pack_price_asn_dn = df_top_asn_dn.groupby('ASN/DN #')['Pack Price'].mean()

plt.figure(figsize=(10,5))
plt.barh(average_pack_price_asn_dn.index, average_pack_price_asn_dn.values, color=colors)
plt.ylabel('ASN/DN #')
plt.xlabel('Average Pack Price')
plt.title('Average Pack Price by ASN/DN #')
plt.show()

# %% [markdown]
# This visualization allows us to compare the average pack price across different ASN/DN#. As you can see, the average pack price varies significantly between different ASN/DN#.

# %%
# Select top 10 countries by number of shipments for clearer visualization
top_countries = df['Country'].value_counts().index[:10]
df_top_countries = df[df['Country'].isin(top_countries)]

average_pack_price_country = df_top_countries.groupby('Country')['Pack Price'].mean()

plt.figure(figsize=(10,5))
plt.barh(average_pack_price_country.index, average_pack_price_country.values, color=colors)
plt.ylabel('Country')
plt.xlabel('Average Pack Price')
plt.title('Average Pack Price by Country')
plt.show()

# %% [markdown]
# As you can see, the average pack price varies significantly between different countries.

# %%
# Select top 10 'Managed By' by number of shipments for clearer visualization
top_managed_by = df['Managed By'].value_counts().index[:10]
df_top_managed_by = df[df['Managed By'].isin(top_managed_by)]

average_pack_price_managed_by = df_top_managed_by.groupby('Managed By')['Pack Price'].mean()

plt.figure(figsize=(10,5))
plt.bar(average_pack_price_managed_by.index, average_pack_price_managed_by.values, color=colors)
plt.xlabel('Managed By')
plt.ylabel('Average Pack Price')
plt.title('Average Pack Price by Managed By')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This visualization allows us to compare the average pack price across different 'Managed By' categories. As you can see, the average pack price varies significantly between different 'Managed By' categories.

# %%
# Select top 10 'Fulfill Via' by number of shipments for clearer visualization
top_fulfill_via = df['Fulfill Via'].value_counts().index[:10]
df_top_fulfill_via = df[df['Fulfill Via'].isin(top_fulfill_via)]

average_pack_price_fulfill_via = df_top_fulfill_via.groupby('Fulfill Via')['Pack Price'].mean()

plt.figure(figsize=(10,5))
plt.bar(average_pack_price_fulfill_via.index, average_pack_price_fulfill_via.values, color=colors)
plt.xlabel('Fulfill Via')
plt.ylabel('Average Pack Price')
plt.title('Average Pack Price by Fulfill Via')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  As you can see, the average pack price varies significantly between different 'Fulfill Via' categories.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Project Code                  10324 non-null  object
#  1   PQ #                          7643 non-null   object
#  2   PO / SO #                     10324 non-null  object
#  3   ASN/DN #                      10324 non-null  object
#  4   Country                       10324 non-null  object
#  5   Managed By                    10324 non-null  object
#  6   Fulfill Via                   10324 non-null  object
#  7   Vendor INCO Term              4920 non-null   object
#  8   Shipment Mode                 9964 non-null   object
#  9   PQ First Sent to Client Date  7643 non-null   object
#  10  PO Sent to Vendor Date        4592 non-null   object
#  11  Scheduled Delivery Date       10324 non-null  object
# ...
